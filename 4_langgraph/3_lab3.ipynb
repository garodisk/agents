# %% [markdown]
# ## Welcome to Week 4, Day 4
#
# This is the start of an AWESOME project! Really simple and very effective.

# %% [markdown]
# ### First - a heads up for Windows PC users
#
# While executing this notebook, you might hit a problem with the Playwright browser raising a NotImplementedError.
#
# This should work when we move to python modules, but it can cause problems in Windows in a notebook.
#
# If you it this error and would like to run the notebook, you need to make a small change which seems quite hacky!
#
# 1. Right click in `.venv` in the File Explorer on the left and select "Find in folder"
# 2. Search for `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())`
# 3. That code should be found in a line of code in a file called `kernelapp.py`
# 4. Comment out that line of code in that file! And save the file. (And in fact, student William Lapa tells me that he needed to comment out the entire else statement that this line is part of.)
# 5. Restart the kernel by pressing the "Restart" button above
#
# Thank you to student Nicolas for finding this, and to Yaki, Zibin and Bhaskar for confirming that this worked for them!

# %%
from typing import Annotated
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START
from langgraph.graph.message import add_messages
from dotenv import load_dotenv
from IPython.display import Image, display
import gradio as gr
from langgraph.prebuilt import ToolNode, tools_condition
import requests
import os
from langchain.agents import Tool

from langchain_openai import ChatOpenAI
from langgraph.checkpoint.memory import MemorySaver

# %%
load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Asynchronous LangGraph
#
# To run a tool:
# Sync: `tool.run(inputs)`
# Async: `await tool.arun(inputs)`
#
# To invoke the graph:
# Sync: `graph.invoke(state)`
# Async: `await graph.ainvoke(state)`

# %%
class State(TypedDict):
    
    messages: Annotated[list, add_messages]


graph_builder = StateGraph(State)

# %%
pushover_token = os.getenv("PUSHOVER_TOKEN")
pushover_user = os.getenv("PUSHOVER_USER")
pushover_url = "https://api.pushover.net/1/messages.json"

def push(text: str):
    """Send a push notification to the user"""
    requests.post(pushover_url, data = {"token": pushover_token, "user": pushover_user, "message": text})

tool_push = Tool(
        name="send_push_notification",
        func=push,
        description="useful for when you want to send a push notification"
    )

# %% [markdown]
# ### Next: Install Playwright
#
# On Windows and MacOS:
# `playwright install`
#
# On Linux:
# `playwright install —with-reps chromium`

# %%
# !python -m playwright install

# %%
# !playwright install
# Out:
# Downloading Chromium 136.0.7103.25 (playwright build v1169) from https://cdn.playwright.dev/dbazure/download/playwright/builds/chromium/1169/chromium-win64.zip
# |                                                                                |   0% of 144.4 MiB
# |■■■■■■■■                                                                        |  10% of 144.4 MiB
# |■■■■■■■■■■■■■■■■                                                                |  20% of 144.4 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■                                                        |  30% of 144.4 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                                |  40% of 144.4 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                        |  50% of 144.4 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                |  60% of 144.4 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                        |  70% of 144.4 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                |  80% of 144.4 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■        |  90% of 144.4 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■| 100% of 144.4 MiB
# Chromium 136.0.7103.25 (playwright build v1169) downloaded to C:\Users\saket\AppData\Local\ms-playwright\chromium-1169
# Downloading Chromium Headless Shell 136.0.7103.25 (playwright build v1169) from https://cdn.playwright.dev/dbazure/download/playwright/builds/chromium/1169/chromium-headless-shell-win64.zip
# |                                                                                |   0% of 89.1 MiB
# |■■■■■■■■                                                                        |  10% of 89.1 MiB
# |■■■■■■■■■■■■■■■■                                                                |  20% of 89.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■                                                        |  30% of 89.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                                |  40% of 89.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                        |  50% of 89.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                |  60% of 89.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                        |  70% of 89.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                |  80% of 89.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■        |  90% of 89.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■| 100% of 89.1 MiB
# Chromium Headless Shell 136.0.7103.25 (playwright build v1169) downloaded to C:\Users\saket\AppData\Local\ms-playwright\chromium_headless_shell-1169
# Downloading Firefox 137.0 (playwright build v1482) from https://cdn.playwright.dev/dbazure/download/playwright/builds/firefox/1482/firefox-win64.zip
# |                                                                                |   0% of 92.1 MiB
# |■■■■■■■■                                                                        |  10% of 92.1 MiB
# |■■■■■■■■■■■■■■■■                                                                |  20% of 92.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■                                                        |  30% of 92.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                                |  40% of 92.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                        |  50% of 92.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                |  60% of 92.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                        |  70% of 92.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                |  80% of 92.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■        |  90% of 92.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■| 100% of 92.1 MiB
# Firefox 137.0 (playwright build v1482) downloaded to C:\Users\saket\AppData\Local\ms-playwright\firefox-1482
# Downloading Webkit 18.4 (playwright build v2158) from https://cdn.playwright.dev/dbazure/download/playwright/builds/webkit/2158/webkit-win64.zip
# |                                                                                |   0% of 57.1 MiB
# |■■■■■■■■                                                                        |  10% of 57.1 MiB
# |■■■■■■■■■■■■■■■■                                                                |  20% of 57.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■                                                        |  30% of 57.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                                |  40% of 57.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                        |  50% of 57.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                |  60% of 57.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                        |  70% of 57.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                |  80% of 57.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■        |  90% of 57.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■| 100% of 57.1 MiB
# Webkit 18.4 (playwright build v2158) downloaded to C:\Users\saket\AppData\Local\ms-playwright\webkit-2158
# Downloading FFMPEG playwright build v1011 from https://cdn.playwright.dev/dbazure/download/playwright/builds/ffmpeg/1011/ffmpeg-win64.zip
# |                                                                                |   0% of 1.3 MiB
# |■■■■■■■■                                                                        |  10% of 1.3 MiB
# |■■■■■■■■■■■■■■■■                                                                |  20% of 1.3 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■                                                        |  30% of 1.3 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                                |  40% of 1.3 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                        |  50% of 1.3 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                |  60% of 1.3 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                        |  70% of 1.3 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                |  80% of 1.3 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■        |  90% of 1.3 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■| 100% of 1.3 MiB
# FFMPEG playwright build v1011 downloaded to C:\Users\saket\AppData\Local\ms-playwright\ffmpeg-1011
# Downloading Winldd playwright build v1007 from https://cdn.playwright.dev/dbazure/download/playwright/builds/winldd/1007/winldd-win64.zip
# |                                                                                |   1% of 0.1 MiB
# |■■■■■■■■                                                                        |  10% of 0.1 MiB
# |■■■■■■■■■■■■■■■■                                                                |  20% of 0.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■                                                        |  30% of 0.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                        |  50% of 0.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                |  62% of 0.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                        |  74% of 0.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                |  87% of 0.1 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■| 100% of 0.1 MiB
# Winldd playwright build v1007 downloaded to C:\Users\saket\AppData\Local\ms-playwright\winldd-1007

# %% [markdown]
# ### Introducing nest_asyncio
#
# Python async code only allows for one "event loop" processing aynchronous events.
#
# The `nest_asyncio` library patches this, and is used for special situations, if you need to run a nested event loop.

# %%
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ### The LangChain community
#
# One of the remarkable things about LangChain is the rich community around it.
#
# Check this out:

# %%
from langchain_community.agent_toolkits import PlayWrightBrowserToolkit
from langchain_community.tools.playwright.utils import create_async_playwright_browser

async_browser =  create_async_playwright_browser(headless=False)  # headful mode
toolkit = PlayWrightBrowserToolkit.from_browser(async_browser=async_browser)
tools = toolkit.get_tools()

# %%
for tool in tools:
    print(f"{tool.name}={tool}")
# Out:
# click_element=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\saket\AppData\Local\ms-playwright\chromium-1169\chrome-win\chrome.exe> version=136.0.7103.25>
# navigate_browser=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\saket\AppData\Local\ms-playwright\chromium-1169\chrome-win\chrome.exe> version=136.0.7103.25>
# previous_webpage=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\saket\AppData\Local\ms-playwright\chromium-1169\chrome-win\chrome.exe> version=136.0.7103.25>
# extract_text=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\saket\AppData\Local\ms-playwright\chromium-1169\chrome-win\chrome.exe> version=136.0.7103.25>
# extract_hyperlinks=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\saket\AppData\Local\ms-playwright\chromium-1169\chrome-win\chrome.exe> version=136.0.7103.25>
# get_elements=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\saket\AppData\Local\ms-playwright\chromium-1169\chrome-win\chrome.exe> version=136.0.7103.25>
# current_webpage=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\saket\AppData\Local\ms-playwright\chromium-1169\chrome-win\chrome.exe> version=136.0.7103.25>

# %%
tool_dict = {tool.name:tool for tool in tools}

navigate_tool = tool_dict.get("navigate_browser")
extract_text_tool = tool_dict.get("extract_text")

    
await navigate_tool.arun({"url": "https://www.cnn.com"})
text = await extract_text_tool.arun({})

# %%
import textwrap
print(textwrap.fill(text))
# Out:
# Breaking News, Latest News and Videos | CNN CNN values your feedback
# 1. How relevant is this ad to you? 2. Did you encounter any technical
# issues? No Video player was slow to load content Video content never
# loaded Ad froze or did not finish loading Video content did not start
# after ad Audio on ad was too loud Other issues Ad never loaded Ad
# prevented/slowed the page from loading Content moved around while ad
# loaded Ad was repetitive to ads I've seen previously Other issues
# Cancel Submit Thank You! Your effort and contribution in providing
# this feedback is much
# appreciated. Close Ad Feedback Close icon US World Politics Business
# Health Entertainment Underscored Style Travel Sports Science Climate
# Weather Ukraine-Russia War Israel-Hamas War Games More US World
# Politics Business Health Entertainment Underscored Style Travel Sports
# Science Climate Weather Ukraine-Russia War Israel-Hamas War Games
# Watch Listen Live TV Subscribe Sign in My Account Settings Newsletters
# Topics you follow Sign out Your CNN account Sign in to your CNN
# account Sign in My Account Settings Newsletters Topics you follow Sign
# out Your CNN account Sign in to your CNN account Live TV Listen Watch
# Edition US International Arabic Español Edition US International
# Arabic Español US Crime + Justice World Africa Americas Asia Australia
# China Europe India Middle East United Kingdom Politics Trump Facts
# First CNN Polls 2025 Elections Business Tech Media Calculators Videos
# Markets Pre-markets After-Hours Fear & Greed Investing Markets Now
# Nightcap Health Life, But Better Fitness Food Sleep Mindfulness
# Relationships CNN Underscored Electronics Fashion Beauty Health &
# Fitness Home Reviews Deals Gifts Travel Outdoors Pets Entertainment
# Movies Television Celebrity Tech Innovate Foreseeable Future Mission:
# Ahead Work Transformed Innovative Cities Style Arts Design Fashion
# Architecture Luxury Beauty Video Travel Destinations Food & Drink Stay
# Videos Sports Pro Football College Football Basketball Baseball Soccer
# Olympics Hockey Science Space Life Unearthed Climate Solutions Weather
# Weather Video Climate Ukraine-Russia War Israel-Hamas War Watch Live
# TV CNN Headlines CNN Shorts Shows A-Z CNN10 CNN Max CNN TV Schedules
# FlashDocs Listen CNN 5 Things Chasing Life with Dr. Sanjay Gupta The
# Assignment with Audie Cornish One Thing Tug of War CNN Political
# Briefing The Axe Files All There Is with Anderson Cooper All CNN Audio
# podcasts Games Daily Crossword Jumble Crossword Photo Shuffle
# Sudoblock Sudoku 5 Things Quiz About CNN Subscribe Photos
# Investigations CNN Profiles CNN Leadership CNN Newsletters Work for
# CNN Follow CNN info The top numbered articles will be viewable to
# readers when programmed onto a page. Make sure you have 30 or more
# cards added to the container for the machine learning (ML) feature to
# work. Your queued up articles, seen in the violet section, will use ML
# to surface up relevant content to the reader based on their individual
# interests and preferences. Live Updates Hurricane Erin Trending Target
# CEO steps down Lisa Cook Abu Dhabi ‘KPop Demon Hunters’ Powerball
# jackpot New York Yankees Oasis reunion tour info The top numbered
# articles will be viewable to readers when programmed onto a page. Make
# sure you have 30 or more cards added to the container for the machine
# learning (ML) feature to work. Your queued up articles, seen in the
# violet section, will use ML to surface up relevant content to the
# reader based on their individual interests and preferences. • Live
# Updates Live Updates Amoreena Barnes Live Updates Hurricane Erin is
# stirring up nearly 30-foot waves well offshore as it continues north
# North Carolina’s coast will get rocked by massive waves as the storm
# makes its closest approach today. Follow here for live updates. Anna
# Moneymaker/Getty Images/File Trump admin strips ocean and air
# pollution monitoring from next-gen weather satellites The Trump
# administration will remove ocean and air pollution monitoring
# instruments from the upcoming fleet of weather satellites, and cut the
# number of satellites, as well. • Video 0:44 CNN Video Storm seen from
# space heading near East Coast 0:44 Impacts from Hurricane Erin, a
# category two hurricane, are expected to begin in North Carolina on
# Wednesday. While Erin is not expected to make landfall, beaches across
# states including New Jersey, New York City, and Virginia have been
# closed to swimmers as strong waves are forecast. • Video 0:40 CNN
# Video Officials: Hurricane’s waves could wash homes to sea 0:40
# Hurricane Erin is churning up life-threatening rip currents and
# dangerous waves along much of the East Coast, sending destructive
# waves to North Carolina’s Outer Banks. CNN’s Dianne Gallagher reports.
# info The top numbered articles will be viewable to readers when
# programmed onto a page. Make sure you have 30 or more cards added to
# the container for the machine learning (ML) feature to work. Your
# queued up articles, seen in the violet section, will use ML to surface
# up relevant content to the reader based on their individual interests
# and preferences. Joe Raedle/Getty Images Target’s CEO is stepping down
# as customers turn away Target CEO Brian Cornell is stepping down after
# 11 years at the retailer, as the company faces slumping sales and
# backlash to its retreat on DEI. Craig T Fruchtman/Getty Images What
# went wrong at Target A timeline of the highs and lows for Target under
# the tenure of outgoing CEO Brian Cornell. • Video 2:35 Joe
# Raedle/Getty Images Video What Target’s CEO said about Trump’s tariffs
# this morning 2:35 Target CEO Brian Cornell is stepping down after 11
# years at the retailer, as the company faces slumping sales and
# backlash to its retreat on DEI.  Michael Fiddelke, Target’s current
# chief operating officer, will replace Cornell on February 1, 2026.
# CNN’s Vanessa Yurkevich reports. info The top numbered articles will
# be viewable to readers when programmed onto a page. Make sure you have
# 30 or more cards added to the container for the machine learning (ML)
# feature to work. Your queued up articles, seen in the violet section,
# will use ML to surface up relevant content to the reader based on
# their individual interests and preferences. Judge rejects Trump admin
# request to release Epstein documents Show all US District Court for
# the Southern District of New York Federal judge said the DOJ could
# release its entire investigation file and its request for grand jury
# transcripts is a ‘diversion’ A federal judge said he would not unseal
# grand jury transcripts and evidence from the investigation into
# Jeffrey Epstein – rejecting the Justice Department’s request to make
# them public. Chip Somodevilla/Getty Images North America/Getty Images
# Pam Bondi tightens grip on Justice Department after Epstein files
# fallout Pam Bondi has emerged from self-exile following right-wing
# blowback over her handling of the Jeffrey Epstein files and is
# reasserting control over the Justice Department and her role as
# attorney general. info The top numbered articles will be viewable to
# readers when programmed onto a page. Make sure you have 30 or more
# cards added to the container for the machine learning (ML) feature to
# work. Your queued up articles, seen in the violet section, will use ML
# to surface up relevant content to the reader based on their individual
# interests and preferences. Trump administration Eric Lee for CNN Vance
# derides protesters while visiting National Guard at Union Station •
# Analysis Analysis Nathan Howard/Reuters/File Analysis Trump’s ‘war
# hero’ comment is his latest flippant comparison of himself to troops
# Al Drago/Bloomberg/Getty Images Trump is pressuring yet another top
# Federal Reserve official to resign info The top numbered articles will
# be viewable to readers when programmed onto a page. Make sure you have
# 30 or more cards added to the container for the machine learning (ML)
# feature to work. Your queued up articles, seen in the violet section,
# will use ML to surface up relevant content to the reader based on
# their individual interests and preferences. Play CNN Headlines -
# Source: CNN Video Watch the latest CNN Headlines info The top numbered
# articles will be viewable to readers when programmed onto a page. Make
# sure you have 30 or more cards added to the container for the machine
# learning (ML) feature to work. Your queued up articles, seen in the
# violet section, will use ML to surface up relevant content to the
# reader based on their individual interests and preferences. José
# Capriles/Penn State Who does this temple belong to? New discovery
# could shed light on a lost society • Video 2:30 CNN Video ‘Killing the
# love of everyone’s lives’: Actress describes brutal scene 2:30 • B/R
# B/R Jonathan Bachman/Getty Images B/R Tim Tebow buys another hockey
# team info The top numbered articles will be viewable to readers when
# programmed onto a page. Make sure you have 30 or more cards added to
# the container for the machine learning (ML) feature to work. Your
# queued up articles, seen in the violet section, will use ML to surface
# up relevant content to the reader based on their individual interests
# and preferences. More Top Stories Erin Hooley/AP/File Obama calls
# Newsom’s redistricting plan ‘a responsible approach’ in response to
# Texas Republicans redrawing maps French streamer dies live online
# after apparent extreme challenge ‘Good moral character,’ too many
# tourists, the latest K-pop hit: Catch up on the day’s stories Video
# Abby Phillip responds to reality TV star’s false claims on slavery
# 2:23 For Subscribers Judge weighs whether to shut down Alligator
# Alcatraz. One big question keeps coming up Ari Shapiro, ‘All Things
# Considered’ co-host, is exiting NPR amid funding cuts Southwest
# announced yet another way it’s becoming just a regular airline Video
# ‘It’s nuts’: Lawmaker reacts to Trump referring to himself as a ‘war
# hero’ 1:38 info The top numbered articles will be viewable to readers
# when programmed onto a page. Make sure you have 30 or more cards added
# to the container for the machine learning (ML) feature to work. Your
# queued up articles, seen in the violet section, will use ML to surface
# up relevant content to the reader based on their individual interests
# and preferences. Russia and ukraine • Analysis Analysis Pierre
# Crom/Getty Images Analysis Ukraine wants a ‘ceasefire,’ Putin and
# Trump want a ‘peace deal.’ Here’s the big difference The first might
# be the only way out of the current violence. The second would be
# against international law. Andrew Harnik/Getty Images Witkoff
# delivered Russian medal from Putin to family of American killed
# fighting for Russia in 2024 US special envoy Steve Witkoff delivered a
# Russian medal to the grieving family of an American who was killed
# fighting for Russia in 2024, a senior administration official told
# CNN. • Analysis for Subscribers Analysis for Subscribers Getty
# Images/AP Analysis for Subscribers Why Putin may never be ready to
# meet with Zelensky Doing so would require the Russian leader to
# “accept the failure of sitting down with a president he considers a
# joke from a country that doesn’t exist” info The top numbered articles
# will be viewable to readers when programmed onto a page. Make sure you
# have 30 or more cards added to the container for the machine learning
# (ML) feature to work. Your queued up articles, seen in the violet
# section, will use ML to surface up relevant content to the reader
# based on their individual interests and preferences. Health • For
# Subscribers For Subscribers Eli Imadali for CNN For Subscribers Jake
# Scott is fighting the pandemic that followed Covid, and it’s only
# getting worse Dr. Jake Scott is on the front line of his second
# pandemic in five years and he is not getting much sleep. Elijah
# Nouvelage/Getty Images HHS staffers implore RFK Jr. to ‘stop spreading
# inaccurate health information’ in wake of CDC shooting More than 750
# current and former staffers at the US Health and Human Services
# implored Secretary Robert F. Kennedy, Jr. in a letter Wednesday to
# “stop spreading inaccurate health information” after a shooter fired
# hundreds of rounds at the headquarters of the US Centers for Disease
# Control and Prevention earlier this month. Ad Feedback info The top
# numbered articles will be viewable to readers when programmed onto a
# page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences. Ad
# Feedback CNN Underscored Molly Flores/CNN Underscored Dermatologists
# say these are the 35 best face serums to reduce wrinkles, acne and
# more Jul 29, 2025 Hoka Hoka’s new addition to the editor-loved Mach
# sneaker line nails fashion and function Aug 20, 2025 Lululemon The
# best We Made Too Much discounted finds to shop this week Aug 19, 2025
# Ad Feedback info The top numbered articles will be viewable to readers
# when programmed onto a page. Make sure you have 30 or more cards added
# to the container for the machine learning (ML) feature to work. Your
# queued up articles, seen in the violet section, will use ML to surface
# up relevant content to the reader based on their individual interests
# and preferences. The business of food Joe Raedle/Getty Images
# McDonald’s is cutting prices of its combo meals to convince customers
# it’s affordable again Pizza Hut Pizza Hut hopes a new $5 pizza will
# bring back customers Courtesy Olive Garden Inflation has increased.
# The price of Olive Garden’s ‘Never Ending Pasta Bowl’ hasn’t info The
# top numbered articles will be viewable to readers when programmed onto
# a page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences.
# Middle east Marton Monus/Reuters Israel launches diplomatic attacks on
# its Western allies ahead of Palestinian statehood recognition • Video
# 6:28 CNN Video Freed hostage says he lives with guilt every day 6:28
# Tamir Kalifa/Getty Images Israel’s West Bank settlement plan could
# ‘bury’ the prospect of a Palestinian state. Here’s why info The top
# numbered articles will be viewable to readers when programmed onto a
# page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences. For
# Subscribers • For Subscribers For Subscribers Angel
# Garcia/Bloomberg/Getty Images For Subscribers Overtourism has hit
# several European hotspots – and locals are getting fed up • For
# Subscribers For Subscribers Eric Thayer/Bloomberg/Getty Images For
# Subscribers The fever gripping the housing market seems to be
# breaking. Here’s why • For Subscribers For Subscribers Rachel Jessen
# for CNN For Subscribers This hospice worker was an atheist. Then a
# patient showed him some astonishing deathbed photos Ad Feedback Ad
# Feedback CNN Underscored info The top numbered articles will be
# viewable to readers when programmed onto a page. Make sure you have 30
# or more cards added to the container for the machine learning (ML)
# feature to work. Your queued up articles, seen in the violet section,
# will use ML to surface up relevant content to the reader based on
# their individual interests and preferences. Best-in-class Molly
# Flores/CNN Underscored Shackets are the greatest mash-up since jorts.
# Here are stylists’ 17 favorites 17 game-changing car products our
# editors never drive without, starting at $5 This backpack will let you
# skip the carry-on Don’t get stuck in the storm. Here’s everything you
# need to stay safe during hurricane season Sleep better knowing you
# saved big with these 31 early Labor Day mattress deals info The top
# numbered articles will be viewable to readers when programmed onto a
# page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences.
# Expert-backed guides Rachel Dennis/CNN Underscored We asked
# podiatrists to share their shoe recommendations from Skechers I put
# Gucci’s $1K horsebit loafers against a cheap pair from Amazon to see
# if they’re worth it I’m over 50, and this is the makeup I swear by for
# a youthful complexion Self-cleaning litter boxes are an actual life-
# changer. Here are the 3 best Keep your items safe with this anti-theft
# travel crossbody bag info The top numbered articles will be viewable
# to readers when programmed onto a page. Make sure you have 30 or more
# cards added to the container for the machine learning (ML) feature to
# work. Your queued up articles, seen in the violet section, will use ML
# to surface up relevant content to the reader based on their individual
# interests and preferences. Editors' picks Molly Flores/CNN Underscored
# The beloved Bonne Maman Advent Calendar is still going strong. Grab it
# before it’s gone 10 Amazon deals happening this week that will
# complete your summer I tested 34 water bottles. Only these 3 are worth
# your money The best toaster ovens of 2025, tried and tested Your
# ultimate guide to the American Express Membership Rewards program info
# The top numbered articles will be viewable to readers when programmed
# onto a page. Make sure you have 30 or more cards added to the
# container for the machine learning (ML) feature to work. Your queued
# up articles, seen in the violet section, will use ML to surface up
# relevant content to the reader based on their individual interests and
# preferences. CNN Sports Julio Aguilar/Getty Images New York Yankees
# hit franchise record nine home runs, make MLB history Years after
# abuse reports, ex-coach at US gymnastics academy is arrested by FBI
# Texas QB Arch Manning says his grandpa apologized for NFL plan
# prediction Video Why is everyone talking about the mixed doubles at
# the US Open? 1:39 info The top numbered articles will be viewable to
# readers when programmed onto a page. Make sure you have 30 or more
# cards added to the container for the machine learning (ML) feature to
# work. Your queued up articles, seen in the violet section, will use ML
# to surface up relevant content to the reader based on their individual
# interests and preferences. Bleacher Report Show all Pro pickleball
# team sells for $13M Video: Former undrafted QB in tears after signing
# NFL contract Ranking of highest-paid tennis players Tiger to lead PGA
# committee on modernizing golf Rugby star regrets NFL stint Ad Feedback
# More from CNN info The top numbered articles will be viewable to
# readers when programmed onto a page. Make sure you have 30 or more
# cards added to the container for the machine learning (ML) feature to
# work. Your queued up articles, seen in the violet section, will use ML
# to surface up relevant content to the reader based on their individual
# interests and preferences. Lisa Phillips/Bureau of Land Management A
# sunny spot where desert, mountains and cultures mix info The top
# numbered articles will be viewable to readers when programmed onto a
# page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences.
# Particle These surprising materials are the future of furniture design
# info The top numbered articles will be viewable to readers when
# programmed onto a page. Make sure you have 30 or more cards added to
# the container for the machine learning (ML) feature to work. Your
# queued up articles, seen in the violet section, will use ML to surface
# up relevant content to the reader based on their individual interests
# and preferences. Barry Chin/The Boston Globe/Getty Images 20 of the
# greatest American dishes you should try info The top numbered articles
# will be viewable to readers when programmed onto a page. Make sure you
# have 30 or more cards added to the container for the machine learning
# (ML) feature to work. Your queued up articles, seen in the violet
# section, will use ML to surface up relevant content to the reader
# based on their individual interests and preferences. Csaba Tokolyi
# Explore incredible diving beneath the streets of Budapest info The top
# numbered articles will be viewable to readers when programmed onto a
# page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences.
# Business Hamad I Mohammed/Reuters Elon Musk pushes back on report he’s
# dropped plans for America Party AI and tech stocks slide as summer
# rally peters out Analysis Corporate America is silent as Trump
# abandons free-market principles Our phones are flooded with apps.
# Google wants to help info The top numbered articles will be viewable
# to readers when programmed onto a page. Make sure you have 30 or more
# cards added to the container for the machine learning (ML) feature to
# work. Your queued up articles, seen in the violet section, will use ML
# to surface up relevant content to the reader based on their individual
# interests and preferences. Politics Kent Nishimura/Bloomberg/Getty
# Images/File Trump admin expands ‘good moral character’ requirement to
# become naturalized citizen Texas GOP nears vote on new maps as
# Democrats stage protest in state House DC residents feel less safe
# after Trump police takeover: Poll info The top numbered articles will
# be viewable to readers when programmed onto a page. Make sure you have
# 30 or more cards added to the container for the machine learning (ML)
# feature to work. Your queued up articles, seen in the violet section,
# will use ML to surface up relevant content to the reader based on
# their individual interests and preferences. US news Julio Cortez/AP
# Parents of girls killed in Texas camp flooding say ‘common sense’
# measures were absent New evidence shows Travis Decker is the only
# suspect in his daughters’ killings, sheriff’s office says Judge rules
# that some Texas schools don’t have to display Ten Commandments in
# classrooms info The top numbered articles will be viewable to readers
# when programmed onto a page. Make sure you have 30 or more cards added
# to the container for the machine learning (ML) feature to work. Your
# queued up articles, seen in the violet section, will use ML to surface
# up relevant content to the reader based on their individual interests
# and preferences. Entertainment David Crotty/Patrick McMullan via Getty
# Images Aubrey Plaza is ‘functioning,’ but it’s a ‘daily struggle’
# after her husband’s death Netflix Everything you need to know about
# ‘KPop Demon Hunters’ Dimitrios Kambouris/Cindy Ord/Jerritt
# Clark/Tommaso Boddi/Getty Images Katie Holmes, James Van Der Beek and
# ‘Dawson’s Creek’ cast to reunite for charity script reading info The
# top numbered articles will be viewable to readers when programmed onto
# a page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences.
# Science and Discovery • Video 1:22 Joel Sartore/National Geographic
# Photo Ark Video This photographer has snapped photos of 17,000
# different species - and he’s not done 1:22 Jennifer Barros &
# MGambaRios/Bat Conservation International Mexico’s bat man on saving
# the ‘most unfairly treated animals on Earth’ Amy Rector/Virginia
# Commonwealth University Fossils show two types of ancient human
# ancestors lived in the same place at the same time info The top
# numbered articles will be viewable to readers when programmed onto a
# page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences.
# Travel Mitchell Overton/AP Ranger fired for hanging transgender flag
# in Yosemite and park visitors may face prosecution Courtesy Miral
# Watch out, Orlando, a new world theme park capital is rising in the
# Arabian desert Csaba Tokolyi Miles from the ocean, there’s incredible
# diving beneath the streets of Budapest info The top numbered articles
# will be viewable to readers when programmed onto a page. Make sure you
# have 30 or more cards added to the container for the machine learning
# (ML) feature to work. Your queued up articles, seen in the violet
# section, will use ML to surface up relevant content to the reader
# based on their individual interests and preferences. Design for Impact
# Show all URA A low-lying Asian country’s defense against rising seas?
# Its very own ‘Long Island’ • Video 3:29 CNN Video Why this architect
# thinks concrete design is ‘ugly, lifeless, dangerous’ 3:29 Irina
# Boersma The bee population is in decline. These designers have a
# solution info The top numbered articles will be viewable to readers
# when programmed onto a page. Make sure you have 30 or more cards added
# to the container for the machine learning (ML) feature to work. Your
# queued up articles, seen in the violet section, will use ML to surface
# up relevant content to the reader based on their individual interests
# and preferences. Health and wellness • Analysis Analysis Francesco
# Carta fotografo/Moment RF/Getty Images Analysis Your kid is using AI
# for homework this year. Now what? NineLives/E+/Getty Images
# ‘Romantasy’ is on the rise, but reading for pleasure has fallen
# drastically over the past 20 years Mary Altaffer/AP In break with
# current CDC recommendations, leading pediatrics group recommends
# Covid-19 shots for young children info The top numbered articles will
# be viewable to readers when programmed onto a page. Make sure you have
# 30 or more cards added to the container for the machine learning (ML)
# feature to work. Your queued up articles, seen in the violet section,
# will use ML to surface up relevant content to the reader based on
# their individual interests and preferences. Climate CNN Where on Earth
# you are determines the kind of climate change you get, scientists say
# Akhtar Soomro/Reuters What are cloudbursts and why might a warming
# world make them even more dangerous? Ian Forsyth/Getty Images Climate
# pollution is making GPS and communications satellites even more
# vulnerable to solar storms Paid Content Intriguing Discoveries info
# The top numbered articles will be viewable to readers when programmed
# onto a page. Make sure you have 30 or more cards added to the
# container for the machine learning (ML) feature to work. Your queued
# up articles, seen in the violet section, will use ML to surface up
# relevant content to the reader based on their individual interests and
# preferences. • Video 1:50 Joe Wilde • Video 1:50 Video Crab vs.
# machine: Robot tests fiddler crab courtship tactics 1:50 info The top
# numbered articles will be viewable to readers when programmed onto a
# page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences.
# TanyaJoy/iStockphoto/Getty Images Ancient viral DNA may play a key
# role in early human development, new study suggests Ad Feedback info
# The top numbered articles will be viewable to readers when programmed
# onto a page. Make sure you have 30 or more cards added to the
# container for the machine learning (ML) feature to work. Your queued
# up articles, seen in the violet section, will use ML to surface up
# relevant content to the reader based on their individual interests and
# preferences. CNN Games + Quizzes Show all • Today's crossword Today's
# crossword CNN Today's crossword No pencil or eraser required •
# Sudoblock Sudoblock CNN Sudoblock Sudoku + Blocks = addictive tile-
# matching puzzle • Jumble Crossword Jumble Crossword CNN Jumble
# Crossword Test your smarts with this scrambled word game • Weekly news
# quiz Weekly news quiz cnn Weekly news quiz What do you remember from
# the week that was? Paid Partner Content In case you missed it info The
# top numbered articles will be viewable to readers when programmed onto
# a page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences.
# Fadel Senna/AFP/Getty Images Elaborate $25 million diamond heist ends
# in a swift recovery and multiple arrests info The top numbered
# articles will be viewable to readers when programmed onto a page. Make
# sure you have 30 or more cards added to the container for the machine
# learning (ML) feature to work. Your queued up articles, seen in the
# violet section, will use ML to surface up relevant content to the
# reader based on their individual interests and preferences. Russia
# gifts motorcycle to Alaska man after Trump-Putin meeting Why is a
# Spanish soccer match set to be held in the US so controversial? White
# House joins TikTok after delaying enforcement of sale-or-ban law
# Allies are working on sorting out feasible security guarantees for
# Ukraine. Here’s why it’s so complex Quentin Tarantino reveals what his
# ‘best’ movie is DOJ prosecutor investigating NY Attorney General
# Letitia James seen posing for photos outside of her home Natasha
# Rothwell reveals her inspiring and ‘delulu’ true story about paying
# off her student loans Subscribe Sign in My Account Settings
# Newsletters Topics you follow Sign out Your CNN account Sign in to
# your CNN account Live TV Listen Watch US Crime + Justice World Africa
# Americas Asia Australia China Europe India Middle East United Kingdom
# Politics Trump Facts First CNN Polls 2025 Elections Business Tech
# Media Calculators Videos Markets Pre-markets After-Hours Fear & Greed
# Investing Markets Now Nightcap Health Life, But Better Fitness Food
# Sleep Mindfulness Relationships CNN Underscored Electronics Fashion
# Beauty Health & Fitness Home Reviews Deals Gifts Travel Outdoors Pets
# Entertainment Movies Television Celebrity Tech Innovate Foreseeable
# Future Mission: Ahead Work Transformed Innovative Cities Style Arts
# Design Fashion Architecture Luxury Beauty Video Travel Destinations
# Food & Drink Stay News Videos Sports Pro Football College Football
# Basketball Baseball Soccer Olympics Hockey Science Space Life
# Unearthed Climate Solutions Weather Weather Video Climate Ukraine-
# Russia War Israel-Hamas War Watch Live TV CNN Headlines CNN Shorts
# Shows A-Z CNN10 CNN Max CNN TV Schedules FlashDocs Listen CNN 5 Things
# Chasing Life with Dr. Sanjay Gupta The Assignment with Audie Cornish
# One Thing Tug of War CNN Political Briefing The Axe Files All There Is
# with Anderson Cooper All CNN Audio podcasts Games Daily Crossword
# Jumble Crossword Photo Shuffle Sudoblock Sudoku 5 Things Quiz About
# CNN Subscribe Photos Investigations CNN Profiles CNN Leadership CNN
# Newsletters Work for CNN Watch Listen Live TV Follow CNN Subscribe
# Sign in My Account Settings Newsletters Topics you follow Sign out
# Your CNN account Sign in to your CNN account Terms of Use Privacy
# Policy Manage Cookies Ad Choices Accessibility & CC About Subscribe
# Newsletters Transcripts Help Center © 2025 Cable News Network. A
# Warner Bros. Discovery Company. All Rights Reserved. CNN Sans ™ & ©
# 2016 Cable News Network. Privacy Policy For privacy options, please
# see our privacy policy: https://www.cnn.com/privacy . Back Button
# Cookie List Search Icon Filter Icon Clear checkbox label label Apply
# Cancel Consent Leg.Interest checkbox label label checkbox label label
# checkbox label label Close Legal Terms and Privacy By clicking
# "Agree", you have read and agree to the Terms of Use and agree to the
# collection and use of your information by cookies and similar
# technologies, as set forth in our Privacy Policy . Agree

# %%
all_tools = tools + [tool_push]

# %%
llm = ChatOpenAI(model="gpt-4o-mini")
llm_with_tools = llm.bind_tools(all_tools)


def chatbot(state: State):
    return {"messages": [llm_with_tools.invoke(state["messages"])]}

# %%
graph_builder = StateGraph(State)
graph_builder.add_node("chatbot", chatbot)
graph_builder.add_node("tools", ToolNode(tools=all_tools))
graph_builder.add_conditional_edges( "chatbot", tools_condition, "tools")
graph_builder.add_edge("tools", "chatbot")
graph_builder.add_edge(START, "chatbot")

memory = MemorySaver()
graph = graph_builder.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
config = {"configurable": {"thread_id": "10"}}

async def chat(user_input: str, history):
    result = await graph.ainvoke({"messages": [{"role": "user", "content": user_input}]}, config=config)
    return result["messages"][-1].content


gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7868
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7868/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
